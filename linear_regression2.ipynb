# %%
import pandas as pd;

# %%
import numpy as np

# %%
from sklearn import linear_model;

# %%
df=pd.read_excel("C:\\Users\\Sathish\\OneDrive\\Desktop\\data set\\house.xlsx");

# %%
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[["Area"]],df[["Price"]]);

# %%
print(reg.predict([[3300]]));
# Out:
# [[628715.75342466]]
# C:\Users\Sathish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
reg.coef_
# Out:
# array([[135.78767123]])

# %%
reg.intercept_
# Out:
# array([180616.43835616])

# %%
#  y=mx+c

y=135.78767123*3300+180616.43835616;

# %%
y
# Out:
# 628715.75341516

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Graph");
plt.xlabel("Price");
plt.ylabel("Area");
plt.scatter(df.Area,df.Price);
plt.plot(df[["Area"]],reg.predict(df[["Area"]]),color="black");

# %%
df1=pd.read_excel("C:\\Users\\Sathish\\OneDrive\\Desktop\\data set\\house1.xlsx");

# %% [markdown]
# #

# %%
df1

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df1[["Area"]],df[["Price"]]);

# %%
print(reg.predict([[8700]]));

# %%
reg.coef_

# %%
reg.intercept_

# %%
plt.title("Graph");
plt.xlabel("Price");
plt.ylabel("Area");
plt.scatter(df1[["Area"]],df[["Price"]]);
plt.plot(df1[["Area"]],reg.predict(df1[["Area"]]),color="Red");
